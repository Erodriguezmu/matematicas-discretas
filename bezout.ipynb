# %% [markdown]
# Encuentre v y w con va+wb=d cuando ambos son positivos
#
#
# ```
# 93 y 42
# 93= 2*42+9
# 42= 4*9+6
# 9= 1*6+3
# 6=2*3+0
# mcd=3
#
# 3 = d = v93+w42
# 9 = 93-2*42
# 6 = 42- 4*9
# 3 = 9- 1*(42- 4*9)
# 3 = -1*42 + 5*9
# 3 = -1*42 + 5*(93-2*42)
# 3 = -11*42 + 5*93
# w=-11 y v=93
#
# ```
#
#
# ```
# 70 y 29
# 70=2*29+12
# 29=2*12+5
# 12=2*5+2
# 5=2*2+1
# 2=2*1+0
# mcd=1
#
#
# 1=d= v70 + w29
# 12 = 70-2*29
# 5 = 29-2*12
# 2 = 12-2*5
# 1 = 5-2*(12-2*5)
# 1 = -2*12 +5*5
# 1 = -2*12 +5*(29-2*12)
# 1 = -12*12 +5*29
# 1 = -12*(70-2*29) +5*29
# 1 = -12*70 +29*29
# v = -12 y w = 29
# ```
#
#
#
#
#
# identidad de bezout para:
#
# ```
# -112 y -91
# d= -112v -91w
# 112 = 1*91+21
# 91 = 4*21+7
# 21 = 3*7+0
# mcd = 7
# 7 = d = 112v +91w
# 21 =112- 1*91
# 7 = 91 - 4*21
# 7 = 91 - 4*(112- 1*91)
# 7 = 5*91- 4*112
# v=4 y w=-5
# d= -112*(4) -91*(-5)
#
# ```
#
#
#
# ```
# -105 y 3
# d = -105v +3w
# 105 = 35*3+0
# mcd=3
#
# 3 = d = 105v + 3w
# v=0 y w=1
#
# ```
