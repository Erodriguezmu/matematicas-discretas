# %% [markdown]
# Encuentre los residuos minimos de los siguientes enteros modulo 6
#
#
#
# ```
# 7+3
# a - qn          |
# 7 - 1(6)=1      |3-0(6)=3
# 7 ≡ 1(mod 6)    |3 ≡ 3(mod 6)
# 7+3 ≡ 1+3 mod(6)
#
# ```
# ```
#  23-24
#  a - qn
#  23-3(6)=23-18=5
#  23≡ 5(mod 6)
#  al estar tan cercanos se puede saber que
#  24≡ 5+(24-23)(mod 6)
#  24≡ 5+(1)(mod 6)
#  24≡ 0(mod 6)
#  23-24≡5-0 (mod 6)
# ```
# ```
#  601-6001
#  ambos a la misma diferencia de multiplos de 6
#  601≡ 1(mod 6)
#  6001≡ 1(mod 6)
#  601-6001≡ 1-1(mod 6)
#  601-6001≡ 0(mod 6)
# ```
# ```
#  7-3
#  7 ≡ 1(mod 6)    |-3 ≡ 3(mod 6)
#  7-3 ≡ 1-3 mod(6)
#  7-3 ≡ -2 mod(6)
# ```
# ```
#  67+68
#  67-11(6)=67-66=1
#  67≡ 1(mod 6)
#  al estar tan cercanos se puede saber que
#  68≡ 1+1(mod 6)
#  68≡ 2(mod 6)
#  67+68≡1+2 (mod 6)
# ```
# ```
#  -3-19
# -1≤-3/6<0       | -4≤-19/6<-3
# a - qn          |
# -3-(-1*6)=3      |-19-(-4*6)=5
# -3 ≡ 3(mod 6)    |-19 ≡ 5(mod 6)
# -3-19 ≡ 3-5 mod(6)
# ```
#
#
#
#
# Encuentre los residuos minimos de los siguientes enteros modulo 10
#
# ```
# 6+4
# a - qn          |
# 6 - 0(10)=6      |4-0(10)=4
# 6 ≡ 6(mod 10)    |4 ≡ 4(mod 10)
# 6+4 ≡ 6+4 mod(10)
# ```
# ```
# 14-7
# a - qn          |
# 14 - 1(10)=4      |-7-(-1*10)=3
# 14 ≡ 4(mod 10)    |-7 ≡ 3(mod 10)
# 14-7 ≡ 4-3 mod(10)
# ```
# ```
# 13-15
# a - qn          |
# 13 - 1(10)=3      |-15-(-1*10)=-5
# 13 ≡ 3(mod 10)    |-15 ≡ -5(mod 10)
# 13-7 ≡ 3-5 mod(10)
# ```
# ```
# -21-17
# -21 - -3(10)=9      |-17-(-2*10)=3
# -21 ≡ 9(mod 10)    |-17 ≡ 3(mod 10)
# -21 -7 ≡ 9-3 mod(10)
# ```
# ```
# 101+11+1
# 101 ≡ 1(mod 10)
# 11 ≡ 1(mod 10)
# 1≡ 1(mod 10)
# 101+11+1 ≡ 3(mod 10)
# ```
# ```
# 101+11-1
# 101 ≡ 1(mod 10)
# 11 ≡ 1(mod 10)
# -1≡ 9(mod 10)
# 101+11-1 ≡ 1(mod 10)
# ```
