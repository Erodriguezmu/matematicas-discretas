# %%
def euclides(a, b):
    while b != 0:
        a, b = b, a % b
    return a

euclides(209, 78)
# Out:
# 1

# %% [markdown]
# usar el algoritmo de euclides para calcular el MCD
# ```
# 209 y 78
# 209 = 2*78+53
# 78 = 1*53+25
# 53 = 2*25+3
# 25 = 8*3+1
# 3 = 2*1+1
# 1 = 1*1+0
# MCD = 1
# ```
#
#
# ```
# 138 y 61
# 138 =2*61+16
# 61 = 3*16+13
# 16 = 1*13+3
# 13 = 4*3+1
# 3 = 2*1+1
# 1 = 1*1+0
# MCD = 1
# ```
#
#
#
# ```
# 93 y 27
# 93 = 3*27+12
# 27 = 2*12+3
# 12 = 4*3+0
# MCD = 3
# ```
#
#
#
# ```
# 231 y 49
# 231 = 4*49+35
# 49 = 1*35+14
# 35 = 2*14+7
# 14 = 2*7+0
# MCD = 7
# ```
